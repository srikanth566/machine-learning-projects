# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"D:\machine learning projects\poc(proof of concept) projects\model_selection_with _seaborn\iris.csv")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc=MinMaxScaler()

# %%
DF=sc.fit(df.drop(['species'],axis=1))

# %%
features=sc.transform(df.drop(['species'],axis=1))

# %%
Df=pd.DataFrame(features,columns=df.columns[:-1])

# %%
Df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0      0.222222     0.625000      0.067797     0.041667
# 1      0.166667     0.416667      0.067797     0.041667
# 2      0.111111     0.500000      0.050847     0.041667
# 3      0.083333     0.458333      0.084746     0.041667
# 4      0.194444     0.666667      0.067797     0.041667

# %%
import seaborn as sns

# %%
sns.pairplot(df,hue='species')

# %% [markdown]
# ###### From the pair plot we can see that data points in some features like sepal length and sepal width are overlapping which cannot be classified by a single or best fit line so we cannot use svm .Decision tree and random forest are the algorthims which classifies the data much efficently which is overlapped.so from the pair plot we can get an idea of which model can be used for the data.
